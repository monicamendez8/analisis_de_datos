# %% [markdown]
# # *Detección de Enfermedades Cardíacas con Webapp*
#
# ![fitness-app.png](data:image/png;base64,...)

# %% [markdown]
# # ▶1 Problema. 📂
#
# <h1> <font color="#FFF9B9"> En las siguientes ciudades: Cleveland (Estados Unidos), Hungary (Europa central), Switzerland (Europa Central), y VA Long Beach (Hospital Naval de veteranos Estados Unidos),  las personas  con edades de 20 - 80 años, con la ayuda del Webapp se hizo, una detección acerca de las enferemdades cardiacas, con el fin de prevenir a tiempo los infartos en ese rango de edades.  </font> </h1>
#
# <h1> <font color="#FFF9B9">La utilización de la app de detección de enfermedades cardíacas se debe principalmente a la falta de ejercicio y hábitos alimenticios inadecuados. Estos factores contribuyen al desarrollo de condiciones que afectan la salud del corazón, y la app puede ser una herramienta útil para identificar riesgos potenciales y fomentar cambios en el estilo de vida.  </font> </h1>
#
# <h1> <font color="#FFF9B9">Con el respaldo de los datos obtenidos a través de la Webapp, se busca no solo educar, sino también motivar a las personas a adoptar un enfoque proactivo respecto a su salud. La integración de tecnología en la detección y prevención de enfermedades ha facilitado la accesibilidad a información valiosa y personalizada.Estas medidas han incentivado la formación de redes comunitarias donde se comparten logros y se fomenta la responsabilidad mutua. Asimismo, se están organizando eventos de salud en los que se ofrecen consultas gratuitas y charlas sobre nutrición, lo cual no solo mejora el acceso a información necesaria, sino que también refuerza el vínculo entre los profesionales de la salud y la comunidad. Con cada paso hacia una mayor concienciación y acción colectiva, se fortalece la esperanza de construir un entorno más saludable, donde la prevención y el cuidado del corazón se conviertan en una prioridad compartida por todos.
#  </font> </h1>
#
# <center>
# <h1> <font color="#A6C8FF">🔤 ¿Cómo prevenir los infartos en las personas con edades entre 20 -80 años?  </font> </h1>
#
# </center>

# %% [markdown]
# #▶ 2 Objetivos. 🆎
#
# <h1> <font color="#FFF9B9"> - Explorar la base de datos. </font> </h1>
# <h1> <font color="#FFF9B9"> - Reprocesar los datos. </font> </h1>
# <h1> <font color="#FFF9B9"> - Visualización de los datos. </font> </h1>
# <h1> <font color="#FFF9B9"> - Conclusiones.  </font> </h1>

# %% [markdown]
# # ▶ 3 Librerias. 📑

# %%
#Importat librerias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # ▶ 4 Carga de los datos. ⏳

# %%
df=pd.read_csv('/content/UCI_Heart_Disease_Dataset_Combined.csv')
df.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40    1              1        140          289          0           0
# 1   49    0              2        160          180          0           0
# 2   37    1              1        130          283          0           1
# 3   48    0              3        138          214          0           0
# 4   54    1              2        150          195          0           0
#
#    MaxHR  ExerciseAngina  Oldpeak  HeartDisease
# 0    172               0      0.0             0
# 1    156               0      1.0             1
# 2     98               0      0.0             0
# 3    108               1      1.5             1
# 4    122               0      0.0             0

# %% [markdown]
# # ▶ 5 Análisis de las columnas de los datos: categóricas y numéricas. ✍

# %%
df.columns = ['Edad', 'Sexo', 'TipodeChequeo', 'ReposoBP', 'Colesterol', 'AyunoBS', 'ReposoECG', 'MaxHR', 'EjercicioAngenia', 'PicoViejo', 'Cardiopatia']
df['Sexo'] = df['Sexo'].replace({0: 'Masculino', 1: 'Femenino'})
df.head()
# Out:
#    Edad       Sexo  TipodeChequeo  ReposoBP  Colesterol  AyunoBS  ReposoECG  \
# 0    40   Femenino              1       140         289        0          0
# 1    49  Masculino              2       160         180        0          0
# 2    37   Femenino              1       130         283        0          1
# 3    48  Masculino              3       138         214        0          0
# 4    54   Femenino              2       150         195        0          0
#
#    MaxHR  EjercicioAngenia  PicoViejo  Cardiopatia
# 0    172                 0        0.0            0
# 1    156                 0        1.0            1
# 2     98                 0        0.0            0
# 3    108                 1        1.5            1
# 4    122                 0        0.0            0

# %%
df.columns
# Out:
# Index(['Edad', 'Sexo', 'TipodeChequeo', 'ReposoBP', 'Colesterol', 'AyunoBS',
#        'ReposoECG', 'MaxHR', 'EjercicioAngenia', 'PicoViejo', 'Cardiopatia'],
#       dtype='object')

# %% [markdown]
# ## ▶ 5.1 Descripción de la tabla. ✍
#
# <center>
#
# <h1> <font color="#A6C8FF">🔤 Según la tabla anterior la información de los datos son los siguientes:  </font> </h1>
# </center>
#
# <h1> <font color="#FFF9B9">
# 💙 ChestPainType: Esto clasifica el tipo de dolor en el pecho experimentado por el individuo. Los valores son: </font> </h1>
# <h1> <font color="#A6C8FF">
# Valor 1: Angina típica, que es dolor en el pecho relacionado con el corazón. </font> </h1>
# <h1> <font color="#A6C8FF">
# Valor 2: Angina atípica, que es dolor en el pecho no relacionado con el corazón. </font> </h1>
# <h1> <font color="#A6C8FF">
# Valor 3: Dolor no anginal, que es típicamente agudo y no continuo. </font> </h1>
# <h1> <font color="#A6C8FF">
# Valor 4: Asintomático, lo que significa que el individuo no experimenta síntomas.  </font> </h1>
#
# <h1> <font color="#FFF9B9">
# 💙 RestingBP: Esta es la presión arterial en reposo individual (en mm Hg) cuando están en reposo.  </font> </h1>
#
# <h1> <font color="#FFF9B9">
# 💙 Colesterol: Este es el nivel de colesterol individual, medido en mg/dl. </font> </h1>
#
# <h1> <font color="#FFF9B9">
# 💙 AyunoBS O FastingBS: Esto indica si el azúcar en sangre en ayunas individual es mayor de 120 mg/dl, sirve para medir la diabetis.
# <h1> <font color="#A6C8FF">
# Se representa como un valor binario donde 1 significa verdadero y 0 significa falso. </font> </h1>
#
# <h1> <font color="#FFF9B9">
# 💙 MaxHR: Esta es la frecuencia cardíaca máxima alcanzada por el individuo.  </font> </h1>
#
# <h1> <font color="#FFF9B9">
# 💙 ExerciseAngina: Esto indica si el individuo experimenta angina (dolor en el pecho) inducida por el ejercicio. </font> </h1>
#
# <h1> <font color="#A6C8FF">
# Se representa como un valor binario donde 1 significa sí y 0 significa no.  </font> </h1>
#
# <h1> <font color="#FFF9B9">
# 💙 PicoViejo: es la medición del electrocardigrama con respecto al impulso de los vasos sanguíneos hacia el corazón.  </font> </h1>
#
# <h1> <font color="#FFF9B9">
# 💙 Cardiopatia: Es una enfermedad que afecta el corazón o los vasos sanguíneos. </font> </h1>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2943 entries, 0 to 2942
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Edad              2943 non-null   int64
#  1   Sexo              2943 non-null   object
#  2   TipodeChequeo     2943 non-null   int64
#  3   ReposoBP          2943 non-null   int64
#  4   Colesterol        2943 non-null   int64
#  5   AyunoBS           2943 non-null   int64
#  6   ReposoECG         2943 non-null   int64
#  7   MaxHR             2943 non-null   int64
#  8   EjercicioAngenia  2943 non-null   int64
#  9   PicoViejo         2943 non-null   float64
#  10  Cardiopatia       2943 non-null   int64
# dtypes: float64(1), int64(9), object(1)
# memory usage: 253.0+ KB

# %% [markdown]
# # ▶6 Estadisticas básicas. 📈

# %%
df.describe()
# Out:
#               Edad  TipodeChequeo     ReposoBP   Colesterol      AyunoBS  \
# count  2943.000000    2943.000000  2943.000000  2943.000000  2943.000000
# mean     52.381923       1.363575   138.698267   253.515121     0.225280
# std      13.037189       1.142614    24.623198   112.724716     0.417838
# min      20.000000       0.000000     0.000000     0.000000     0.000000
# 25%      44.000000       0.000000   120.500000   204.000000     0.000000
# 50%      54.000000       1.000000   134.000000   248.000000     0.000000
# 75%      61.000000       2.000000   150.000000   306.000000     0.000000
# max      80.000000       3.000000   200.000000   603.000000     1.000000
#
#          ReposoECG        MaxHR  EjercicioAngenia    PicoViejo  Cardiopatia
# count  2943.000000  2943.000000       2943.000000  2943.000000  2943.000000
# mean      0.626911   144.040095          0.412504     1.570031     0.548420
# std       0.713650    28.446327          0.492369     1.585102     0.497735
# ...

# %% [markdown]
# ### ▶6.1 Datos duplicados.

# %%
duplicate_rows_df = df[df.duplicated()]
print("\nDuplicate Rows except the first occurrence based on all columns are:")
print(duplicate_rows_df)
# Out:
# Duplicate Rows except the first occurrence based on all columns are:
#       Edad       Sexo  TipodeChequeo  ReposoBP  Colesterol  AyunoBS  \
# 1933    34  Masculino              1       118         210        0
# 1949    50  Masculino              1       120         244        0
# 1961    46   Femenino              0       120         249        0
# 1973    55   Femenino              0       140         217        0
# 1979    66  Masculino              2       146         278        0
# ...    ...        ...            ...       ...         ...      ...
# 2938    59   Femenino              1       140         221        0
# 2939    60   Femenino              0       125         258        0
# 2940    47   Femenino              0       110         275        0
# 2941    50  Masculino              0       110         254        0
# 2942    54   Femenino              0       120         188        0
#
#       ReposoECG  MaxHR  EjercicioAngenia  PicoViejo  Cardiopatia
# ...

# %%
df = df.drop_duplicates()
print("\nDataFrame after removing duplicates:")
print(df)
# Out:
# DataFrame after removing duplicates:
#       Edad       Sexo  TipodeChequeo  ReposoBP  Colesterol  AyunoBS  \
# 0       40   Femenino              1       140         289        0
# 1       49  Masculino              2       160         180        0
# 2       37   Femenino              1       130         283        0
# 3       48  Masculino              3       138         214        0
# 4       54   Femenino              2       150         195        0
# ...    ...        ...            ...       ...         ...      ...
# 2641    68  Masculino              2       120         211        0
# 2651    44  Masculino              2       108         141        0
# 2657    52   Femenino              0       128         255        0
# 2761    59   Femenino              3       160         273        0
# 2796    54   Femenino              0       120         188        0
#
#       ReposoECG  MaxHR  EjercicioAngenia  PicoViejo  Cardiopatia
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2220 entries, 0 to 2796
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Edad              2220 non-null   int64
#  1   Sexo              2220 non-null   object
#  2   TipodeChequeo     2220 non-null   int64
#  3   ReposoBP          2220 non-null   int64
#  4   Colesterol        2220 non-null   int64
#  5   AyunoBS           2220 non-null   int64
#  6   ReposoECG         2220 non-null   int64
#  7   MaxHR             2220 non-null   int64
#  8   EjercicioAngenia  2220 non-null   int64
#  9   PicoViejo         2220 non-null   float64
#  10  Cardiopatia       2220 non-null   int64
# dtypes: float64(1), int64(9), object(1)
# memory usage: 208.1+ KB

# %% [markdown]
# ## ▶ 6.2 Datos nulos.

# %%
df.isnull().sum()
# Out:
# Edad                0
# Sexo                0
# TipodeChequeo       0
# ReposoBP            0
# Colesterol          0
# AyunoBS             0
# ReposoECG           0
# MaxHR               0
# EjercicioAngenia    0
# PicoViejo           0
# Cardiopatia         0
# dtype: int64

# %% [markdown]
# # ▶ 7 Gráficos. 📈

# %% [markdown]
# ## Gráfico 7.1. Sexo

# %%
fig, ax = plt.subplots(figsize=(6, 6))

x = df['Sexo'].value_counts()
labels = ('Femenino', 'Masculino')

ax.pie(x, labels=labels, autopct='%.1f%%',
       wedgeprops={'linewidth': 3.0, 'edgecolor': 'w'},
       textprops={'size': 'x-large'})
ax.set_title('Sexo (Femenino y masculino)', fontsize=18)
plt.tight_layout()

# %% [markdown]
# <h1> <center> <font color="#A6C8FF">🔤 Análisis gráfico 7.1. Sexo. </center>
#
#  <h1> <font color="#FFF9B9">  Según en el gráfico del sexo, la mayoría de las personas encuestadas fueron las mujeres con un 76.4%, mientras que los hombres fueron menores con un 23,6%, ha mostrado no solo un interés creciente por parte de la comunidad, sino también una disposición a adoptar cambios necesarios, para mejorar la salud frente a las enfermedades cardiacas.  </font> </h1>

# %% [markdown]
# ## Gráfico 7.2. Colesterol vs Sexo.

# %%
sns.catplot(
    data=df, kind="bar",
    y="Colesterol", hue="Sexo",
    errorbar="sd", palette="dark", alpha=.6, height=6
)
plt.title("Colesterol relacionado con el sexo (masculino y femenino)")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# <h1> <center> <font color="#A6C8FF">🔤 Análisis gráfico 7.2. Colesterol vs Sexo.</center>
#
# <h2> <font color="#FFF9B9"> Según los datos en los hombres poseen una mayor cantidad de colesterol, teniendo en cuenta que nuestro cuerpo necesita colesterol para formar células sanas, pero tener altos niveles de colesterol puede aumentar el riesgo de sufrir una enfermedad cardíaca. Mientras que en las mujeres según los datos son menos el nivel de colesterol. Esto nos da a entender que las mujeres tienden menos propensa a sufrir enfermedades cardiacas.

# %% [markdown]
# ## Gráfico 7.3. Colesterol Vs Edad.

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(data=df, x="Edad", y="Colesterol", hue="Sexo")
plt.title("Colesterol relacionado con la edad y el sexo (masculino y femenino)")

plt.show()

# %% [markdown]
# <h1><center> <font color="#A6C8FF">🔤 Análisis gráfico 7.3. Colesterol vs Edad
# </center>
# </p>
#
#   <h1> <font color="#FFF9B9"> Es preocupante ver cómo las mujeres entre 40 y 60 años son más propensas a registrar colesterol alto, en comparación con los hombres. Esta información es crucial para orientar las campañas de prevención y concientización. La promoción de hábitos alimenticios saludables, el ejercicio regular y los chequeos médicos periódicos pueden ayudar a reducir estos riesgos.  </font> </h1>

# %% [markdown]
# ## Gráfico 7.4. Colesterol Vs Sexo frente a las enfermedades cardiacas.

# %%
sns.boxplot(data=df,  x="Colesterol")
plt.title("Colesterol relacionado con el sexo (masculino y femenino)")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %% [markdown]
# ### Limpieza de datos

# %%
df.isna().sum()
# Out:
# Edad                0
# Sexo                0
# TipodeChequeo       0
# ReposoBP            0
# Colesterol          0
# AyunoBS             0
# ReposoECG           0
# MaxHR               0
# EjercicioAngenia    0
# PicoViejo           0
# Cardiopatia         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Valores atipicos con respecto al colesterol y sexo

# %%
Q1 = df["Colesterol"].quantile(0.25)
Q3 = df["Colesterol"].quantile(0.75)
print("Q1:", Q1)
print("Q3:", Q3)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df[(df["Colesterol"] < lower_bound) | (df["Colesterol"] > upper_bound)]
print("Outliers:", df[(df["Colesterol"] < lower_bound) | (df["Colesterol"] > upper_bound)])
# Out:
# Q1: 201.0
# Q3: 325.0
# Outliers:       Edad       Sexo  TipodeChequeo  ReposoBP  Colesterol  AyunoBS  \
# 30      53   Femenino              2       145         518        0
# 76      32   Femenino              3       118         529        0
# 149     54   Femenino              3       130         603        1
# 293     65   Femenino              3       115           0        0
# 294     32   Femenino              0        95           0        1
# ...    ...        ...            ...       ...         ...      ...
# 1886    66  Masculino              1       197           0        0
# 1890    54   Femenino              2       176           0        0
# 1898    46   Femenino              2       147           0        0
# 1911    25  Masculino              1       197           0        0
# 2076    67  Masculino              2       115         564        0
#
#       ReposoECG  MaxHR  EjercicioAngenia  PicoViejo  Cardiopatia
# ...

# %%
Q1 = df["Colesterol"].quantile(0.25)
Q3 = df["Colesterol"].quantile(0.75)
print("Q1:", Q1)
print("Q3:", Q3)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df = df[(df["Colesterol"] >= lower_bound) & (df["Colesterol"] <= upper_bound)]
# Out:
# Q1: 201.0
# Q3: 325.0

# %% [markdown]
# ## Gráfico 7.5. Colesterol vs sexo con respecto al cardiopatia.

# %%
sns.boxplot(data=df,  x="Colesterol")
plt.title("Colesterol relacionado con el sexo (femenino y masculino)")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %% [markdown]
# <h1> <center><font color="#A6C8FF">🔤 Análisis del gráfico 7.5: Colesterol vs sexo con respesto a cardiopatia.</center>
# <p>
#   <h2> <font color="#FFF9B9">
# El mayor índice frente al colesterol, con respecto al sexo están en los hombres, mientras que en las mujeres son menos propensas. </font> </h1>
# <p>
#   <h2> <font color="#FFF9B9">
# Es fundamental reconocer el papel que juega la educación en la prevención de enfermedades cardiovasculares. Se han diseñado programas específicos para impartir conocimientos sobre nutrición, ejercicio y el impacto del estrés en la salud cardíaca. Estas sesiones no solo informan, sino que también empoderan a los participantes, brindándoles las herramientas necesarias para hacer cambios significativos en sus rutinas diarias. A medida que se involucran en estas actividades, se fomenta una comunidad más responsable y consciente de sus decisiones, creando un ciclo virtuoso, donde el intercambio de información y experiencias se convierte en un motor de motivación colectiva. La cultura del cuidado del corazón está en plena expansión, promoviendo una mentalidad proactiva hacia la salud, la cual se manifiesta en una disminución progresiva de factores de riesgo y un aumento en las visitas controles de salud regulares. </font> </h1>

# %% [markdown]
# ## Gráfico 7.6. Edad y Sexo vs ChestPainType (Tipo de dolor en el pecho)

# %%
sns.barplot(data=df, x='TipodeChequeo', y='Edad', hue='Sexo')
plt.title('Edad y Sexo vs ChestPainType (Tipo de dolor en el pecho) ')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# <h1> <center> <font color="#A6C8FF">🔤 Análisis del gráfico 7.7: Edad y sexo con respecto al tipo de chequeo (Tipo de dolor en el pecho). </center>
#
# <h2> <font color="#FFF9B9">
# Según la gráfica es necesario centrarse en los hombres de 50 a 60 años para los chequeos y programas de prevención cardíaca, dada su mayor propensión a dolores de pecho de tipo 1 a 3. El hecho de que las mujeres no presenten síntomas de tipo 4 en este rango de edad puede ser un dato relevante para ajustar los enfoques preventivos.
#
# </font> </h2>

# %% [markdown]
# ## Gráfico 7.7. Edad con respecto al tipo de chequeo.

# %%
flights = (
    df.pivot_table(index="TipodeChequeo", columns="Sexo", values="Edad", aggfunc='mean')
    # Use pivot_table and specify an aggregation function (e.g., mean) to handle duplicate values
)

# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(flights, annot=True, fmt="3f", linewidths=.5, ax=ax)
plt.title('Tipo de chequeo con respecto a la edad')
plt.show()

# %% [markdown]
# <h1> <center> <font color="#A6C8FF">🔤 Análisis del gráfico 7.7: Edad con respecto al tipo de chequeo. </center>
#
#   <h2> <font color="#FFF9B9">
# Es impactante ver cómo ciertos grupos de edad y géneros son más propensos a experimentar síntomas específicos.  Tipo 1: La angina típica, siendo un dolor de pecho relacionado con el corazón, tiene una concentración más alta en hombres de 53-60 años, mientras que las mujeres de la misma edad parecen estar menos afectadas. Es crucial para la salud pública entender estas diferencias para dirigir mejor las políticas de prevención y atención médica.
#
# </font> </h2>
#
#   <h2> <font color="#FFF9B9">
# Por otro lado, en el tipo 2, en el rango de edad de 49-50 años, parece que las mujeres tienen un mayor porcentaje de no presentar síntomas cardíacos, mientras que los hombres muestran una mayor prevalencia de síntomas. Un dato que sin duda puede influir en cómo se abordan las estrategias de salud para estas poblaciones específicas.
#
#  </font> </h2>

# %% [markdown]
# ## Gráfico 7.8. Enfermedades cardiacas  💓.

# %%
labels = ['Cardiopatia', 'AyunoBS', 'EjercicioAngenia']
sections = [56, 85, 75]
colors = ['#ff9999','#99ff99','#66b3ff']
plt.pie(sections, labels=labels, colors=colors,
        startangle=90,
        explode = (0, 0.1, 0), shadow = True, radius = 1.2,
        autopct = '%1.2f%%')

plt.axis('equal')
plt.title('Grafico 7.8. Enfermedades cardiacas')
plt.show()

# %% [markdown]
#  <h1> <center> <font color="#A6C8FF">🔤 Análisis gráfico 7.8: Enfermedades cardiacas.  </center> </
#  <p>
#
#
#  <h2> <font color="#FFF9B9">
# Es importante tener en cuenta que entre la población en general tanto los hombres como las mujeres, tienden a sufrir mayor enfemedades cardicas son el AyunoBS, que significa azúzar en la sangre o diabetes.  </font> </h2>
#
# <h2> <font color="#FFF9B9">
# Además, diabetes es un factor de riesgo significativo para las enfermedades cardíacas en hombres y mujeres. La concentración elevada de azúcar en la sangre puede dañar los vasos sanguíneos y los nervios que controlan el corazón, lo que aumenta el riesgo de problemas cardíacos. Mantener controlados los niveles de azúcar en la sangre es crucial para prevenir complicaciones cardíacas.  </font> </h2>

# %% [markdown]
# ## Gráfico 7.9. AyunoBs es la azúcar en la sangre, con respecto al sexo y la edad.

# %%
flights = (
    df.pivot_table(index="AyunoBS", columns="Sexo", values="Edad", aggfunc='mean')

)


f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(flights, annot=True, fmt="2f", linewidths=.5, ax=ax)
plt.title('AyunoBs es la sangre en la azucar, con respecto al sexo y la edad')
plt.show()

# %% [markdown]
#  <h1> <center> <font color="#A6C8FF">🔤 Análisis gráfico 9. AyunoBs es la azúcar en la sangre, con respecto al sexo y la edad. </center>
#  </
#
#  <h2> <font color="#FFF9B9">
#  Es interesante observar cómo varía la concentración de azúcar en la sangre según el rango de edad y el género. Los hombres entre 51-53 años parecen ser más propensos a la diabetes, mientras que las mujeres de esa misma edad muestran una menor propensión. Al avanzar hacia el rango de edad de 54-60 años, las diferencias entre hombres y mujeres se vuelven mínimas.  </font> </h2>
#
#  <h2> <font color="#FFF9B9">
# Estos patrones pueden proporcionar información valiosa para los programas de prevención y tratamiento a la diabetes. Entender las diferencias de género y edad es crucial para desarrollar estrategias de salud más efectivas.  </font> </h2>

# %% [markdown]
# ## Gráfico 7.10. MaxHR, la frecuencia cardiaca máxima en las personas.

# %%
df['MaxHR'].plot(kind='hist', bins=10, title='MaxHR')
plt.xlabel('MaxHR')
plt.ylabel('Frecuencia')

plt.show()

# %% [markdown]
#  <h1> <center> <font color="#A6C8FF">🔤 Análisis gráfico 7.10:  MaxHR, la frecuencia cardiaca máxima en las personas. </center> </
#  <p>
#
# <h2> <font color="#FFF9B9">
# MaxHR, representa la frecuencia cardiaca máxima en las personas. Es increíble cómo nuestro corazón puede trabajar bajo condiciones de esfuerzo, alcanzando entre 140 y 160 latidos por minuto. Mantenerse dentro de estos rangos durante el ejercicio puede ser seguro y beneficioso para la mayoría de las personas. Sin embargo, siempre es importante consultar a un médico para saber cuál es el rango óptimo para cada individuo.
#
# </font> </h2>

# %% [markdown]
# # ▶ 8. Conclusiones: ✅
#
#  <h2> <font color="#FFF9B9">
#  ✌ Los datos sugieren que las mujeres tienen un alto índice de problemas cardíacos, específicamente relacionados con la presión arterial y preinfartos, lo que puede ser atribuido en parte a:
#
# </font> </h2>
#
# 1. Falta de ejercicio regular.
# 2. Alimentación no saludable.
# 3. Factores de riesgo relacionados con el estilo de vida.
#
#
#  <h2> <font color="#FFF9B9">
# ✌ Es importante destacar que otros factores también pueden contribuir a este problema, como:
#
# </font> </h2>
# 1. Edad avanzada.
# 2. Historia familiar de enfermedades cardíacas.
# 3. Diabetes.
# 4. Obesidad.
# 5. Estrés.
# 6. Falta de sueño.
# 7. Consumo excesivo de sal y grasas saturadas.
#
# <h2> <font color="#FFF9B9">
# ✌ Para reducir el riesgo de enfermedades cardíacas, se recomienda:
#
# </font> </h2>
# 1. Realizar ejercicio regular (al menos 150 minutos semanales).
# 2. Mantener una dieta equilibrada y saludable (rica en frutas, verduras, granos integrales y proteínas magras).
# 3. Controlar la presión arterial y el colesterol.
# 4. Dejar de fumar (si aplica).
# 5. Reducir el estrés a través de técnicas de relajación.
# 6. Dormir lo suficiente (7-8 horas diarias).
# 7. Realizar chequeos médicos regulares.
#
# <h2> <font color="#FFF9B9">
# ✌ Es fundamental que las mujeres tomen conciencia de estos factores de riesgo y adopten hábitos saludables para proteger su salud cardiovascular.
#
# </font> </h2>
# _______________________________________________________________________________
#  <h2> <font color="#FFF9B9">
# ✌ Según los datos, los hombres entre 51-55 años son más propensos a sufrir:
#
#  </font> </h2>
#
# 1. Infartos (ataques cardíacos)
# 2. Comas diabéticos
# 3. Problemas relacionados con el azúcar en la sangre (diabetes)
#
#
#
#  <h2> <font color="#FFF9B9">
# Esto se debe principalmente a:
#
#  </font> </h2>
#
# 1. Falta de conciencia sobre la importancia de una alimentación sana
# 2. Consumo excesivo de alimentos procesados y grasosos
# 3. Adicción al tabaco (cigarrillos)
# 4. Falta de actividad física regular
# 5. Estilo de vida sedentario
#
#
#
#  <h2> <font color="#FFF9B9">
# ✌ Otros factores que pueden contribuir a estos problemas son:
#
#
# </font> </h2>
#
# 1. Hipertensión (presión arterial alta)
# 2. Colesterol alto
# 3. Obesidad
# 4. Historia familiar de enfermedades cardíacas o diabetes
# 5. Estrés crónico.
#
#
#  <h2> <font color="#FFF9B9">
# ✌ Es crucial que los hombres en este rango de edad tomen medidas preventivas, como:
#
# </font> </h2>
#
# 1. Realizar chequeos médicos regulares
# 2. Adoptar una dieta equilibrada y saludable
# 3. Practicar ejercicio regular (al menos 150 minutos semanales)
# 4. Dejar de fumar
# 5. Reducir el estrés a través de técnicas de relajación
# 6. Controlar la presión arterial y el colesterol
# 7. Dormir lo suficiente (7-8 horas diarias)
#
#
#
#  <h2> <font color="#FFF9B9">
# ✌ La conciencia y el cambio de hábitos pueden ayudar a prevenir o controlar estas enfermedades y mejorar la calidad de vida en general.
#
# </font> </h2>
#
# ________________________________________________________________________________
#   <h2> <font color="#A6C8FF">
# ✌ Promover campañas preventivas en estas 3 ciudades es fundamental, especialmente si las mujeres son las más afectadas. La concientización y la educación sobre los riesgos de las enfermedades cardíacas pueden marcar una gran diferencia en la salud pública. Programas de monitoreo y chequeos regulares también son cruciales para detectar problemas a tiempo, que se presentan a diarios en el Hospital Naval UCI.
#
# </font> </h2>
# <h2> <font color="#A6C8FF">
# ✌ Además, la retroalimentación de los participantes será esencial para adaptar los programas a las necesidades reales de la población, garantizando así su relevancia y eficacia. Al mismo tiempo, será importante implementar canales de comunicación que faciliten el diálogo constante entre profesionales de la salud y los miembros de la comunidad, creando un ambiente donde cada voz sea escuchada y valorada. La educación continua sobre los riesgos cardiovasculares debe acompañarse de campañas informativas que utilicen diversos medios, desde redes sociales hasta talleres presenciales, para llegar a un público más amplio y diverso. De esta manera, se generará un entorno propicio para que tanto hombres como mujeres se sientan motivados y equipados para hacer cambios significativos en sus estilos de vida. A medida que se fortalezca esta red de apoyo comunitario, se espera que la cultura del autocuidado se arraigue profundamente, promoviendo una mayor colaboración entre individuos y profesionales en la búsqueda de una salud óptima.
#
# </font> </h2>

# %%
from IPython.display import HTML
HTML('<iframe width="660" height="415" src="https://www.youtube.com/embed/Tbv4jm2IJGk?si=e4UxJ8YHCUstY8M_" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>')
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py:724: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="660" height="415" src="https://www.youtube.com/embed/Tbv4jm2IJGk?si=e4UxJ8YHCUstY8M_" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# # ▶ 9. Mi información. 🔰
# <center>
# <h1> <font color="#FFF9B9"> Para más información contactame. </font> </h1>
#
# <h1> <font color="#A6C8FF">🔤 Mi nombre es: Mónica Alexandra Méndez Ibáñez  </font> </h1>
# <h1> <font color="#A6C8FF">✉  Mi correo es: monalexameniba@gmail.com </font> </h1>
# <h1> <font color="#A6C8FF">⌨ Soy una persona sorda con titulo profesional en Licenciatura en Informática UDENAR - master en análisis de datos  </font> </h1>
